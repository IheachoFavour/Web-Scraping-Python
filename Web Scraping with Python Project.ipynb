# %% [markdown]
# ## Web Scaping (Jumia)

# %%
import pandas as pd
from bs4 import BeautifulSoup 
import requests
import re

# %%
products = []
for i in range(1,51):
    url = f"https://www.jumia.com.ng/mobile-phones/?page={i}#catalog-listing"
    page  = requests.get(url)
    page.encoding = "UTF-8"
    soup = BeautifulSoup(page.text, 'html.parser')
    main_div = soup.find('main', class_ = "has-b2top -pts")
    articles = main_div.find_all('article', class_ = 'prd _fb col c-prd')
    
    for article in articles:
        #Get the names
        name = article.find('h3', class_ = 'name').text.strip()
         
        # Split the name and color
        name_and_color = name.split('-')
        # Extract the color
        if len(name_and_color) > 1:
            color = name_and_color[-1].strip()
        elif 'Grey' in name:
                color = 'Grey'
        elif 'Black' in name:
            color = 'Black'
        else:
            color = 'n/a'
    
        #Get the prices (new and old)
        price = article.find('div' , class_ = 'prc').text.strip()
        price_match = re.search(r'^\₦?\s*\d+(,\d{3})*', price)
        if price_match:
            price_text = price_match.group()
            price_text = price_text.replace('₦', '').strip()
            price = int(price_text.replace(',', ''))
        else:
            price = 'N/A'
            
        old_price_element = article.find('div', class_='old')
        if old_price_element:
            old_price = old_price_element.text.strip()
            old_price_match = re.search(r'^\₦?\s*\d+(,\d{3})*', old_price)
            if old_price_match:
                old_price_text = old_price_match.group()
                old_price_text = old_price_text.replace('₦', '').strip()
                old_price = int(old_price_text.replace(',', ''))
            else:
                old_price = 'N/A'
        else:
            old_price = 'N/A'

    
        #Getting the dicount percentage
        discount_element = article.find('div', class_ = 'bdg _dsct _sm')
        if discount_element:
            discount = discount_element.text.strip()
        else:
            discount = 'N/A'
    
        #Getting the rating
        rating_element = article.find('div', class_ = 'stars _s')
        if rating_element:
            rating = rating_element.text.strip()
        else:
            rating = 'N/A'
    
        #Getting the store
        store = article.find('div', class_='bdg _mall _xs')
        if store:
            store_name = store.text.strip()
        else:
            store_name = 'Not from official store'
    
        #Getting the type of shipping
        shipping_element = article.find('svg', class_ = 'ic xprss')
        if shipping_element:
            shipping_type = shipping_element.attrs['aria-label']
        else:
            shipping_type = 'Normal Shipping'

        #Shipped from?
        shipped_from_element = article.find('div', class_ = 'bdg _glb _xs')
        if shipped_from_element:
            shipped_from = shipped_from_element.text.strip()
        else:
            shipped_from = "Not shipped from abroad"
        
        products.append([name, color, price, old_price, discount, rating, store_name, shipping_type, shipped_from])

# %%
products
# Out:
# [['itel 20000mAh Fast Charging, Bright Torch STAR 200Fast Power Bank',
#   'n/a',
#   15990,
#   19790,
#   '19%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 110 Africa Edition Dual SIM Wireless FM, Torch, Camera Phone',
#   'n/a',
#   13871,
#   18000,
#   '23%',
#   '4.1 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel 2163 Wireless FM Torchlight Dual SIM - Black',
#   'Black',
#   11500,
#   15500,
#   '26%',
#   '4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel 2163 Wireless FM Torchlight Dual SIM - Black',
#   'Black',
#   11494,
#   15000,
#   '23%',
#   '4.2 out of 5',
#   'Official Store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['FreeYond M5,4GB+128GB,4G 6.52" Smartphone 5000mAh,Grey',
#   'Grey',
#   97000,
#   142498,
#   '32%',
#   '3.7 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ["itel S24 6.6'' 8GB RAM/256GB ROM Android 13 -Blue",
#   'Blue',
#   152199,
#   250000,
#   '39%',
#   '4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi A3 6.71" 3GB RAM/64GB ROM Android 12 - Blue',
#   'Blue',
#   97750,
#   110500,
#   '12%',
#   '4.4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 64GB ROM DUAL SIM -5000mAh BLACK',
#   '5000mAh BLACK',
#   112000,
#   160500,
#   '30%',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia C30 6.82" HD+ 3GB RAM/64GB ROM Android 11 - Green',
#   'Green',
#   78560,
#   99500,
#   '21%',
#   '4.4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['FreeYond F9 6.52" 2GB RAM/64GB ROM Android 12 - Blue',
#   'Blue',
#   65863,
#   73563,
#   '10%',
#   '3.9 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel A04 6.3" HD+ Screen, 2GB RAM + 32GB ROM, 4000mAh, 5MP Camera, 3G, Fingerprint & Face Unlock - Cyan +Free Case',
#   'Cyan +Free Case',
#   73710,
#   100000,
#   '26%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['FreeYond F9,2GB+64GB,6.52" Smartphone,4G,5000mAh,Black',
#   'Black',
#   68440,
#   73563,
#   '7%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 128GB ROM DUAL SIM -5000mAh BLACK',
#   '5000mAh BLACK',
#   130000,
#   170000,
#   '24%',
#   '4.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno POP 8 (BG6) 6.6" HD+,64GB ROM/3 GB RAM 5000mAh, 8MP - Black',
#   'Black',
#   107425,
#   120000,
#   '10%',
#   '4.5 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Nokia G21 6.5" 4GB RAM/64GB ROM Android 11 - Nordic Blue',
#   'Nordic Blue',
#   105720,
#   145500,
#   '27%',
#   '4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Nokia C31 - 6.75" HD+ - 3GB/32GB MEMORY- 4G LTE- 5050mAh- Mint',
#   'Mint',
#   77396,
#   99000,
#   '22%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel A18S 5.0" 32GB ROM + Up To 4GB RAM, 5MP, Android 13 - Orange',
#   'Orange',
#   64456,
#   105000,
#   '39%',
#   '4.7 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo 30000Mah Ultra Fast Charging Power Bank',
#   'n/a',
#   30980,
#   53880,
#   '43%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi 12 6.79" 8GB RAM/128GB ROM Android 13 - Midnight Black',
#   'Midnight Black',
#   175350,
#   210000,
#   '17%',
#   '4.2 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi 12 6.79" 8GB RAM/256 GB ROM Android 13-Midnight Black',
#   'Midnight Black',
#   189500,
#   235000,
#   '19%',
#   '4.2 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi A3 6.71" 4 GB RAM/128 GB ROM Android 12 - Green',
#   'Green',
#   112900,
#   130500,
#   '13%',
#   '3.9 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel A70 6.6"HD 4GB RAM 128GB ROM Android 12 - Green',
#   'Green',
#   91200,
#   120000,
#   '24%',
#   '5 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ["XIAOMI Redmi 13C 6.74'' 4GB RAM/128GB ROM Android 12- Green",
#   'Green',
#   119000,
#   140000,
#   '15%',
#   'N/A',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI 13C 8GB RAM- 256GB ROM- 5000MAH- BLACK',
#   'BLACK',
#   165000,
#   197000,
#   '16%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 128GB ROM DUAL SIM -5000mAh BLACK',
#   '5000mAh BLACK',
#   130000,
#   175000,
#   '26%',
#   '4.1 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oppo A3S 99.9%NEW Refurbished 6.2" 4G+64G 13MP 4230mAH FaceUnlock',
#   'n/a',
#   75000,
#   128000,
#   '41%',
#   '4.1 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB/64GB DUAL SIM  5000mAh LIGHT GREEN',
#   'n/a',
#   112000,
#   160000,
#   '30%',
#   '4.6 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 15 Pro Max 512gb - Nano Sim - Natural Titanium',
#   'Natural Titanium',
#   2250000,
#   3300000,
#   '32%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['FreeYond F9,(4+4)GB+64GB,6.52" Smartphone,4G,5000mAh,Grey',
#   'Grey',
#   83700,
#   128533,
#   '35%',
#   '3.6 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi Note 13 6.67" 6GB RAM/128GB ROM Android 12 - Black',
#   'Black',
#   239000,
#   260000,
#   '8%',
#   '4.3 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A05 6.7" 4GB RAM/64GB ROM Android 13 - Black',
#   'Black',
#   106935,
#   150000,
#   '29%',
#   '4.5 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A05 6.7" 4GB RAM/128GB ROM Android 13 - Black',
#   'Black',
#   126500,
#   150000,
#   '16%',
#   '4.4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel P55 6.6", 128GB ROM + Up To 12GB RAM, 50MP, 5000mAh 18W, 4G',
#   'n/a',
#   117127,
#   180000,
#   '35%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel A70 6.6" HD+, 256GB ROM + Up To 12GB RAM, 5000mAh, 13MP, 4G',
#   'n/a',
#   116390,
#   200000,
#   '42%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A15 6.5" 4GB RAM/128GB ROM Android 14 - Blue Black',
#   'Blue Black',
#   199674,
#   380000,
#   '47%',
#   '3.8 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI 13C 4GB RAM- 128GB ROM- 5000MAH- BLACK',
#   'BLACK',
#   135000,
#   139000,
#   '3%',
#   '4.6 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia G10, 6.5" HD+ (4GB RAM, 64GB ROM) Android 11 (13/2/2)MP + 8MP Selfie - 4G - 5050mAh - Fingerprint- Dark Blue',
#   'Dark Blue',
#   93993,
#   115800,
#   '19%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Nokia C30, 6.82" HD+ 3GB RAM + 64GB ROM Android 11 (13MP + 2MP ) + 5PM 4G Dual SIM - White',
#   'White',
#   78075,
#   97990,
#   '20%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo 30000Mah QualityTwo Way Ultra Fast Charging PowerBank',
#   'n/a',
#   29876,
#   55000,
#   '46%',
#   '4.6 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oppo A3S 99.9%NEW Refurbished 6.2" 4G+64G 13MP 4230mAH FaceUnlock',
#   'n/a',
#   75000,
#   128000,
#   '41%',
#   '3.9 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 64GB ROM DUAL SIM -5000mAh BLACK',
#   '5000mAh BLACK',
#   112000,
#   150000,
#   '25%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oppo A31 6GB RAM+128G ROM Refurbished Dual SIM6.5 Inch Screen HD Camera 12MP Face Unlock+Fingerprint Smartphone',
#   'n/a',
#   94999,
#   150999,
#   '37%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel 2163 1.8" Wireless FM Torchlight Dual SIM',
#   'n/a',
#   11630,
#   15000,
#   '22%',
#   '3.9 out of 5',
#   'Official Store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A70 6.6" HD 4GB RAM/256GB ROM Android 12 - Green',
#   'Green',
#   98800,
#   153000,
#   '35%',
#   '5 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Realme C30s 6.5" 3GB RAM/64GB ROM Android 12 - Blue',
#   'Blue',
#   97020,
#   165100,
#   '41%',
#   '4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 64GB ROM DUAL SIM 5000mAh Silver',
#   'n/a',
#   113000,
#   155000,
#   '27%',
#   '4.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel It 5606 2500mAh Big Battery, FM, Facebook,City Blue',
#   'n/a',
#   17700,
#   28000,
#   '37%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Spark 20 (KJ5) 6.6", 128GB + Up To 8GB RAM, 50MP, 5000mAh',
#   'n/a',
#   158837,
#   200000,
#   '21%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["itel S24 6.6'' 8GB RAM/128GB ROM Android 13 - White",
#   'White',
#   165000,
#   250000,
#   '34%',
#   '3 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel 20000mAh Fast,Charging,Bright Torch PowerBank + Free Charger',
#   'n/a',
#   17450,
#   29490,
#   '41%',
#   '3.9 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Vivo Y93s 99.9%NEW Refurbished 6.2" 6G+128G 13MP 4030mAh FaceWake',
#   'n/a',
#   77000,
#   121257,
#   '36%',
#   '3.7 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel 2166 Opera Mini, Torchlight, 1000mAh, Dual SIM - Blue',
#   'Blue',
#   13850,
#   18000,
#   '23%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 20000mAh Dual Input & Dual Output Fast Charging Power Bank',
#   'n/a',
#   15489,
#   76000,
#   '80%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno POP 8 (BG6) 6.6" HD+ 4GB RAM/64GB ROM Android 12 - Green',
#   'Green',
#   111904,
#   138440,
#   '19%',
#   '4.7 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Oppo A3S 99.9%NEW Refurbished 6.2" 4G+64G 13MP 4230mAH FaceUnlock',
#   'n/a',
#   75000,
#   128000,
#   '41%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy  A05 6.7" 4GB RAM/128GB ROM Android 13 - Light Green',
#   'Light Green',
#   126500,
#   150000,
#   '16%',
#   '4.4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 15 Pro Max 512gb - Nano Sim - Blue Titanium',
#   'Blue Titanium',
#   2250000,
#   3300000,
#   '32%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["XIAOMI Redmi 13C 6.74'' 8GB RAM/256GB ROM Android 12- Blue",
#   'Blue',
#   152000,
#   190000,
#   '20%',
#   '4.6 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['AGM Note N1 6.52"  8GB Base RAM/8GB Extended RAM/128GB ROM Android 13 - Grey',
#   'Grey',
#   132500,
#   150000,
#   '12%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A24 6.5" 6GB RAM/128GB ROM Android 13  - Black',
#   'Black',
#   262700,
#   450000,
#   '42%',
#   'N/A',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 64GB ROM DUAL SIM -5000mAh SILVER',
#   '5000mAh SILVER',
#   112000,
#   160500,
#   '30%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia G10, 6.5" HD+ (4GB RAM, 64GB ROM) Android 11 (48/5/2/2)MP + 8MP Selfie - 4G - 5050mAh - Fingerprint- Dusk Purple',
#   'Dusk Purple',
#   93993,
#   115800,
#   '19%',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A70-A665L Android Smart Mobile Phone With 128GB + 3GB',
#   'A665L Android Smart Mobile Phone With 128GB + 3GB',
#   96515,
#   150000,
#   '36%',
#   '3.7 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 13 Pro Max 6.7" Super Retina XDR Display With ProMotion, (6GB RAM + 512GB ROM), IOS 15, 5G, FaceTime - Gold',
#   'Gold',
#   1700000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI NOTE 13 8GB/256GB DUAL SIM-5000MAH- BLACK',
#   'BLACK',
#   268000,
#   350000,
#   '23%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A70 6.6" HD+, 128GB ROM + 3GB RAM, 5000mAh, 13MP + 8MP, 4G',
#   'n/a',
#   105750,
#   140000,
#   '24%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Siccoo Magic Voice Changer Function Four Sim P14 Pro GOLD',
#   'n/a',
#   29100,
#   30000,
#   '3%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 20000mAh Dual Input & Dual Output Fast Charging Power Bank',
#   'n/a',
#   16800,
#   25000,
#   '33%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A18s 5.0" 32GB ROM + Up To 4GB RAM, 5MP, Android 13 - Orange',
#   'Orange',
#   64980,
#   100000,
#   '35%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel It2160 Wireless Fm, Torchlight, Dual SIM - Dark Blue',
#   'Dark Blue',
#   14549,
#   18000,
#   '19%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 2160 Wireless FM, Bright Torchlight - Dark Blue',
#   'Dark Blue',
#   12165,
#   14200,
#   '14%',
#   '4.5 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel It2163,1.77 Screen,Opera Mini, BrightTorch,1000mAh Deep Blue',
#   'n/a',
#   12028,
#   13500,
#   '11%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Realme C51 6.74'' 4GB RAM/128GB ROM Android 13 - Black",
#   'Black',
#   141120,
#   236558,
#   '40%',
#   '3.5 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S20 5G 12+128GB G9810 Single Sim - Gray',
#   'Gray',
#   310400,
#   380000,
#   '18%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo SpacePods X Burna Boy ANC True Wireless Earbuds',
#   'n/a',
#   51400,
#   97950,
#   '48%',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Vivo Y93s 99.9%NEW Refurbished 6.2" 6G+128G 13MP 4030mAh FaceWake',
#   'n/a',
#   77000,
#   150000,
#   '49%',
#   '3.7 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel A70 6.6" HD 4GB RAM/256GB ROM Android 12 - Blue',
#   'Blue',
#   98800,
#   153000,
#   '35%',
#   '5 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel A70 6.6" HD 4GB RAM/256GB ROM Android 12 - Black',
#   'Black',
#   98800,
#   153000,
#   '35%',
#   '4.4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Bontel L400 Plus,1.77 Inch,0.08MP,Feature Phone,1000mAh,Black',
#   'Black',
#   10600,
#   14000,
#   '24%',
#   '4.1 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel Circle 1 Unique Design, Round Screen, Dual SIM Phone - Gold',
#   'Gold',
#   23231,
#   30000,
#   '23%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI A3 3GB/64GB-DUAL SIM-5000MAH-STAR BLUE',
#   'STAR BLUE',
#   104000,
#   110000,
#   '5%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['IPhone 6 64G 4.7" Fingerprint 4G LTE Refurbished Smartphone',
#   'n/a',
#   82256,
#   150000,
#   '45%',
#   '3.8 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi 9A 6.53" 4GB RAM/64GB ROM Android 10 - Black',
#   'Black',
#   108000,
#   150000,
#   '28%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S10 8+128 GB Single Sim Android 9.0 Octa Core 2.8GHz 6.1 Inch Quad HD+ Tri-lens Camera - White',
#   'White',
#   290000,
#   'N/A',
#   'N/A',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo 30000mah Superior Quality  Ultra Fast Charging Power Bank',
#   'n/a',
#   30990,
#   40000,
#   '23%',
#   '4.1 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A04e 6.5" 3GB RAM/64GB ROM Android 12 - Copper',
#   'Copper',
#   99037,
#   300000,
#   '67%',
#   'N/A',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI A3 4GB/128GB-DUAL SIM-5000MAH-FOREST GREEN',
#   'FOREST GREEN',
#   122000,
#   150000,
#   '19%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Camon 20 (CK6) 6.67"  8GB RAM/256GB ROM Android 13 -Black',
#   'Black',
#   269750,
#   300000,
#   '10%',
#   '4.9 out of 5',
#   'Official Store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 15 Pro Max 256gb - Nano Sim - Blue Titanium',
#   'Blue Titanium',
#   2150000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 12 Pro Max - 6.7-Inch - 128GB ROM, 6GB RAM - 2815mAh',
#   '2815mAh',
#   780000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Hot 40i-X6528 Android Smart Phone With 128GB+4GB + FREE UMBRELLA',
#   'X6528 Android Smart Phone With 128GB+4GB + FREE UMBRELLA',
#   140900,
#   210000,
#   '33%',
#   '4.7 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Pop 8 (BG6) 6.6", 3GB RAM(UpTo 6GB) +64GB, 5000mAh, 13MP',
#   'n/a',
#   108380,
#   130000,
#   '17%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo Super Max Fast Charge Powerbank 27000mah + FREE CABLE',
#   'n/a',
#   28120,
#   28990,
#   '3%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A05s 6.6" HD+, 32GB ROM + Up To 4GB RAM, 4000mAh, 4G - Green',
#   'Green',
#   80752,
#   100000,
#   '19%',
#   '4.7 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Vivo Y93s 99.9%NEW Refurbished 6.2" 6G+128G 13MP 4030mAh FaceWake',
#   'n/a',
#   77000,
#   150000,
#   '49%',
#   '4 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['New Age 30000mAh POWER BANK FAST CHARGE TYPE C INPUT & OUTPUT',
#   'n/a',
#   30500,
#   45000,
#   '32%',
#   '4.1 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 5626 2.8" Screen, 2500mAh Battery, Triple SIM, Loudspeaker',
#   'n/a',
#   29051,
#   40000,
#   '27%',
#   '4.2 out of 5',
#   'Official Store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['AGM Note N1 6.52" 8GB Base RAM/8GB Extended RAM/128GB ROM Android 13- Blue',
#   'Blue',
#   132500,
#   150000,
#   '12%',
#   '4.1 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['IPhone 6P 64GB - （Renewed）Silver - 5.5 Inch',
#   '5.5 Inch',
#   83905,
#   119963,
#   '30%',
#   '2 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['IPhone 6P 64GB - （Renewed）Gold - 5.5 Inch',
#   '5.5 Inch',
#   83905,
#   119963,
#   '30%',
#   '3.8 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo 20000mAh Traveler 4  10.5W Smart Charge Power Bank',
#   'n/a',
#   14520,
#   30980,
#   '53%',
#   '3.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno T301 Dual Sim With Camera & TorchLight Fm, Speaker - Blue',
#   'Blue',
#   17071,
#   29000,
#   '41%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['New Age 50000 MaH POWER BANK FAST CHARGE TYPE C INPUT',
#   'n/a',
#   51400,
#   'N/A',
#   'N/A',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone XR - 6.1" - 64GB ROM, 3GB RAM, 2942mAh - Blue',
#   'Blue',
#   760000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Huawei Enjoy 5S 95%NEW Renewed 5" 13MP+5MP 2GB+16GB 2200mAh DualSIM',
#   'n/a',
#   43000,
#   80000,
#   '46%',
#   '2.3 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['IPhone 6P 64GB - (Renewed) Space Gray - 5.5 Inch',
#   '5.5 Inch',
#   83905,
#   100000,
#   '16%',
#   '2.5 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI 13C 6GB RAM- 128GB ROM- 5000MAH- BLACK',
#   'BLACK',
#   145000,
#   160000,
#   '9%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel Flip 1 2.4", Folding Phone, 1200mAh, Dual SIM Feature - Blue',
#   'Blue',
#   36365,
#   50000,
#   '27%',
#   '3.4 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel S24 6.6", 128GB + Up To 8GB RAM, 5000mAh, 108MP Camera, 4G',
#   'n/a',
#   141571,
#   180000,
#   '21%',
#   '4.1 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Spark 20 (KJ5) 6.6" 8GB RAM/256GB ROM Android 13 - Blue',
#   'Blue',
#   187001,
#   231345,
#   '19%',
#   '4.5 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S24 Ultra Dual SIM - 12GB RAM - 512GB - 5G - Black',
#   'Black',
#   1950000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 20000mAh Fast Charge Powerbank With Torch  + Free Charger',
#   'n/a',
#   17440,
#   29250,
#   '40%',
#   '3.9 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 27000mAh Triple Input Fast Charging PowerBank + Fast Charger',
#   'n/a',
#   25990,
#   45000,
#   '42%',
#   '3.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo 30000mah Massive UltraSmart Powerbank',
#   'n/a',
#   30065,
#   48000,
#   '37%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 64GB ROM DUAL SIM -5000mAh GREEN',
#   '5000mAh GREEN',
#   112000,
#   160800,
#   '30%',
#   '4.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Hot 40i (8GB RAM + 256GB RAM) 4G 5000mAh Gold',
#   'n/a',
#   220000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['New Age 22500 Power Bank With Type-C Port Input & Output',
#   'C Port Input & Output',
#   18599,
#   'N/A',
#   'N/A',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 13 - 6.1" - 128GB ROM, 4GB RAM, 3240mAh - White',
#   'White',
#   760000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 13 Pro Max 6.7" Super Retina XDR Display With ProMotion, (6GB RAM + 512GB ROM) IOS 15, 5G, FaceTime - Sierra Blue',
#   'Sierra Blue',
#   1700000,
#   'N/A',
#   'N/A',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 5310 XpressMusic, Bluetooth, MP3, FM, Dual SIM, Color -Black',
#   'Black',
#   31900,
#   35000,
#   '9%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia T20 -10.4” 4GB/64GB, 8MP Camera, LTE - 8200mAh - Ocean Blue',
#   'Ocean Blue',
#   169750,
#   220000,
#   '23%',
#   '4.7 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo 20000mAh Traveler 4  Smart Charge Power Bank',
#   'n/a',
#   14950,
#   30980,
#   '52%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 14 Pro Max 6.7" 256GB Nano Sim - Deep Purple',
#   'Deep Purple',
#   1670000,
#   'N/A',
#   'N/A',
#   '1 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi Note 13 Pro+ 5G 6.67" 8GBRAM/256GBROM Android13 -Black',
#   'Black',
#   582585,
#   615907,
#   '5%',
#   '4.8 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI NOTE 13 6GB/128GB DUAL SIM-5000MAH- BLACK',
#   'BLACK',
#   241000,
#   990000,
#   '76%',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A04 6.3" Screen, 2GB RAM + 32GB ROM, 4000mAh, 5MP AI Camera',
#   'n/a',
#   74195,
#   100000,
#   '26%',
#   '3.9 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A24 6.5" 6GB RAM/128GB ROM Android 13 - Green',
#   'Green',
#   262700,
#   500000,
#   '47%',
#   'N/A',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Tecno T528,2.8 Inch, Radio,Opera Mini, Battery 2500mAH-Gold',
#   'Gold',
#   28700,
#   40500,
#   '29%',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A54 5G 6.4" 8GB RAM/256GB ROM Android 13 - Graphite',
#   'Graphite',
#   490100,
#   850000,
#   '42%',
#   '4.5 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ["Nokia C12, 6.3'' (2GB RAM, 64GB ROM)  (8MP ) Dual SIM - Light Mint",
#   'Light Mint',
#   77105,
#   88500,
#   '13%',
#   '4.7 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Dual Simcard 4g LTE Android Smartphone MI 4X 5.0 Inch Screen',
#   'n/a',
#   48499,
#   69999,
#   '31%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Shipped from abroad'],
#  ['Oppo A31(6GB +128G) Dual SIM 6.5 Inch Refurbished 12MP Red',
#   'n/a',
#   98999,
#   150999,
#   '34%',
#   '4.6 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S10 Plus (S10+) 6.4-Inch AMOLED (8GB, 128GB ROM) (12MP + 12MP + 16MP)+(10MP+8MP) 4G Smartphone - Black',
#   'Black',
#   350000,
#   'N/A',
#   'N/A',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 11 Pro Max - 6.5" - 4GB RAM, 64GB ROM - Gold',
#   'Gold',
#   760000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo 20000MAH Fast Charge Powerbank - Power For Days',
#   'Power For Days',
#   14890,
#   20000,
#   '26%',
#   '3.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Samsung Galaxy S9 5.8'' Inch QHD ( 4GB + 64GB ROM ) 12MP+8MP _ Midnight Black, Single Sim",
#   'Black',
#   179000,
#   250000,
#   '28%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Oppo A3S Refurbished 4GBRAM 64GB -4G LTE Dual SIM 6.2'' Pink",
#   "4G LTE Dual SIM 6.2'' Pink",
#   76999,
#   99999,
#   '23%',
#   '4.4 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel 27000mAh Triple Smart Input Fast Charging PowerBank',
#   'n/a',
#   25860,
#   45000,
#   '43%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 12 6.1" 4GB RAM/128GB ROM IOS 14 - Black',
#   'Black',
#   710999,
#   900999,
#   '21%',
#   '5 out of 5',
#   'Official Store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 128GB ROM DUAL SIM -5000mAh Green',
#   '5000mAh Green',
#   130000,
#   180000,
#   '28%',
#   '4.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['AGM H6 Leather 6.6" 16GB RAM/256GB Android 13 - Black',
#   'Black',
#   210000,
#   297500,
#   '29%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 150 - Dual Sim -2.4" -Camera - Torch-Fm Radio-1020mAh-Black',
#   'Black',
#   27000,
#   'N/A',
#   'N/A',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 6310 Classic Design, Wireless FM Feature Phone',
#   'n/a',
#   31040,
#   32000,
#   '3%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel P55 6.6", 128GB ROM + Up To 12GB RAM, 50MP, 5000mAh 18W, 4G',
#   'n/a',
#   117127,
#   180000,
#   '35%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Smart 8 6.6" 3GB RAM/64GB ROM Android T Go - Galaxy White',
#   'Galaxy White',
#   101200,
#   300000,
#   '66%',
#   'N/A',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung SamsungGalaxy S10 8GB+128GB 1Sim 6.1 Inch QuadHD (BLACK)',
#   'n/a',
#   280000,
#   350000,
#   '20%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Hot 40i (4GB RAM + 128GB ROM) 4G 5000mAh Black',
#   'Black',
#   158000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oppo A31(6GB +128G) Dual SIM 6.5-inch  Refurbished 12MP Cyan',
#   'inch  Refurbished 12MP Cyan',
#   92828,
#   150999,
#   '39%',
#   '3.8 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel 2160 Wireless FM, Bright Torchlight, Call Recorder, Dual SIM Mobile - Blue',
#   'Blue',
#   14113,
#   15000,
#   '6%',
#   '4.2 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Oppo A3S 99.9%NEW Refurbished 6.2" 4G+64G 13MP 4230mAH FaceUnlock',
#   'n/a',
#   75000,
#   128000,
#   '41%',
#   '3.5 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Refurbished Huawei Y9 2020 6.5-inch Fhd+, 8gb+128gb,Blue',
#   'inch Fhd+, 8gb+128gb,Blue',
#   96700,
#   109330,
#   '12%',
#   '3.8 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Zealot S67 Bluetooth Speaker 60W Output Power Bluetooths',
#   'n/a',
#   83999,
#   'N/A',
#   'N/A',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Samsung Galaxy S20 Plus 5G - 6.7'', 128GB / 12GB, Single Sim - Grey",
#   'Grey',
#   350000,
#   'N/A',
#   'N/A',
#   '4.6 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Samsung Galaxy S21 Ultra 5G - 6.8'', 256GB / 12GB, Single Sim -Black",
#   'Black',
#   600000,
#   'N/A',
#   'N/A',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 15 Pro 128gb - Nano Sim - Natural Titanium',
#   'Natural Titanium',
#   1600000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI A3 4GB/128GB-DUAL SIM-5000MAH-MIDNIGHT BLACK',
#   'MIDNIGHT BLACK',
#   121000,
#   150000,
#   '19%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel Circle 1 Unique Design, Round Screen, Dual SIM Phone - Black',
#   'Black',
#   23990,
#   30000,
#   '20%',
#   '3.7 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['New Age 50000mA FC50P POWER BANK FAST CHARGE TYPE C INPUT',
#   'n/a',
#   50500,
#   98000,
#   '48%',
#   '4.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Samsung Galaxy S20 Ultra - 6.9'' - 12GB RAM 128GB ROM,5000mAh -Black",
#   'Black',
#   420000,
#   500000,
#   '16%',
#   '3.7 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy Note 20 5G 6.7" Single Sim (128GB 8GB RAM) - Bronze',
#   'Bronze',
#   380000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 2163 Wireless FM Torchlight Dual SIM - Blue',
#   'Blue',
#   11500,
#   15500,
#   '26%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A54 5G 8GB RAM/128GB ROM Android 13 - Graphite',
#   'Graphite',
#   457400,
#   800000,
#   '43%',
#   '5 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Tecno CAMON 30 (256GB ROM + 8+8GB RAM) 4G 5000mAh - Dark',
#   'Dark',
#   335000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 128GB ROM DUAL SIM 5000mAh Silver',
#   'n/a',
#   130000,
#   155000,
#   '16%',
#   '3.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI A3 3GB/64GB-DUAL SIM-5000MAH-MIDNIGHT BLACK',
#   'MIDNIGHT BLACK',
#   103500,
#   110000,
#   '6%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oraimo 30000mah Quality Ultra Fast Charging Power Bank',
#   'n/a',
#   30021,
#   38000,
#   '21%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel 3310 Feature - Torch Light - 1000mAh - Black',
#   'Black',
#   11640,
#   12000,
#   '3%',
#   '3.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi Note 13 6.67" 8GB RAM/128GB ROM Android 12 - Green',
#   'Green',
#   258700,
#   275000,
#   '6%',
#   '4.9 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Hot 40i (8GB RAM + 256GB RAM) 4G 5000mAh Green',
#   'n/a',
#   220000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Smart 7 HD (X6516) 6.6", 64GB ROM + Up To 4GB, 5000mAh, 8MP',
#   'n/a',
#   108750,
#   120000,
#   '9%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple Iphone 12 Pro Max 256GB - Gold',
#   'Gold',
#   860000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel Tv Torch Black',
#   'Black',
#   31000,
#   'N/A',
#   'N/A',
#   '3.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 13 Pro Max - 6.7" 256GB ROM, 6GB RAM, 4352mA -Silver',
#   'Silver',
#   1070000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel S24 6.6" 256GB + Up To 16GB RAM, 5000mAh, 108MP, Android 13',
#   'n/a',
#   186950,
#   200000,
#   '7%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi Note 13 6.67" 8GB RAM/256 GB ROM Android 12 - Blue',
#   'Blue',
#   276800,
#   375500,
#   '26%',
#   '4.8 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 5310 XpressMusic Wireless FM Loudspeaker Dual SIM -black',
#   'black',
#   31040,
#   35000,
#   '11%',
#   '3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A15 4GB/128GB DUAL SIM BLUE BLACK 5000MAH',
#   'n/a',
#   211000,
#   300000,
#   '30%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno T313,1.8" Dual SIM Mobile Phone - Black',
#   'Black',
#   16530,
#   23000,
#   '28%',
#   '5 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Note 10 Single Sim 256gb 8gb',
#   'n/a',
#   320000,
#   'N/A',
#   'N/A',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel S24 6.6" 128GB + Up To 8GB RAM, 5000mAh, 108MP, Android 13',
#   'n/a',
#   145950,
#   180000,
#   '19%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 20000mAh Fast Charge, Bright Torch SMART MOBILE Power Bank',
#   'n/a',
#   15990,
#   58000,
#   '72%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A04 6.3" HD+ Screen, 2GB RAM + 32GB ROM, 4000mAh, 5MP Camera',
#   'n/a',
#   74292,
#   100000,
#   '26%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Spark 10 Pro 8GB RAM/256GB ROM Android 12- Black',
#   'Black',
#   194950,
#   490000,
#   '60%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Spark 20 Pro (256GB + 8GB RAM) 5000mAh Black',
#   'Black',
#   260310,
#   312375,
#   '17%',
#   '1 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A15 8GB/256GB DUAL SIM BLUE BLACK 5000MAH',
#   'n/a',
#   286500,
#   390000,
#   '27%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel M7- 2.4 Inch, FM, MP3 Mobile Phone - Black',
#   'Black',
#   13580,
#   14000,
#   '3%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A24 6.5" 4GB RAM/128GB ROM Android 13 - Black',
#   'Black',
#   247000,
#   450000,
#   '45%',
#   'N/A',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Spark 10 (KI5q) (128GB Rom +(8+8)16GB RAM) 50MP',
#   'n/a',
#   170000,
#   213000,
#   '20%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['New Age 10500mAh High Speed Power Bank With Dual Output',
#   'n/a',
#   11639,
#   11999,
#   '3%',
#   '3.9 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 13 Pro 6.1 Inch (6GB RAM + 256GB ROM)- Blue',
#   'Blue',
#   1000000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S22 Ultra 5G 128GB ROM 8GB RAM Single Sim - Black',
#   'Black',
#   720000,
#   800000,
#   '10%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel 2720 1.77 Inch Color Display, Flip Phone- RED',
#   'RED',
#   19885,
#   25000,
#   '20%',
#   '4.7 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S8 Plus 64gb 6.2" Single Sim- Black',
#   'Black',
#   200000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A05 4GB RAM 64GB ROM DUAL SIM -5000mAh GREEN',
#   '5000mAh GREEN',
#   111000,
#   150000,
#   '26%',
#   '4.7 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A05 6.7" 4GB RAM/64GB ROM Android 13 - Light Green',
#   'Light Green',
#   106935,
#   150000,
#   '29%',
#   '4.5 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Apple Iphone XS Max 256gb Silver  + Power Bank',
#   'n/a',
#   485000,
#   'N/A',
#   'N/A',
#   '1 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Pop 8 (BG6) 6.6", 64GB ROM + Up To 6GB RAM, 5000mAh - Black',
#   'Black',
#   109990,
#   130000,
#   '15%',
#   '2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 5626 2.8" Screen 2500mAh Battery',
#   'n/a',
#   29950,
#   40000,
#   '25%',
#   '4.5 out of 5',
#   'Official Store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['IPhone 6P 16GB - （Renewed）Silver - 5.5 Inch',
#   '5.5 Inch',
#   79500,
#   119963,
#   '34%',
#   'N/A',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Zealot S67 Waterproof Bluetooth Bass Speaker',
#   'n/a',
#   72459,
#   120900,
#   '40%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI 13C (4GB RAM + 128GB ROM) 5000MAH - Navy Blue',
#   'Navy Blue',
#   129500,
#   155000,
#   '16%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A15 8GB/256GB DUAL SIM BLUE 5000MAH',
#   'n/a',
#   288000,
#   390000,
#   '26%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A05s 6.6" HD+, 64GB ROM + Up To 8GB RAM, 4000mAh, 4G',
#   'n/a',
#   99900,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Spark 20 (KJ5) 6.6" HD+, 128GB ROM + Up To 8GB RAM, 50MP + 32MP Selfie, 5000mAh +18W, G85, 4G, Finger & Face ID - Black',
#   'Black',
#   162780,
#   200000,
#   '19%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['New Age 22500 Power Bank With Type-C Port Input & Output',
#   'C Port Input & Output',
#   22000,
#   25000,
#   '12%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A05s 6.6" HD+ Screen, 2GB RAM + 32GB ROM, 4000mAh, 4G LTE, 5MP Dual Camera, Fingerprint & Face Unlock - Green +Free Case',
#   'Green +Free Case',
#   83750,
#   100000,
#   '16%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A05s 6.6" HD+, 32GB ROM + Up To 4GB RAM, 4000mAh, 4G - Black',
#   'Black',
#   81431,
#   100000,
#   '19%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['New Age 50000 MAH DIGITAL SMART POWER BANK WITH TYPE C INPUT',
#   'n/a',
#   51750,
#   'N/A',
#   'N/A',
#   '4.1 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 2166 Opera Mini, Torchlight, 1000mAh, Dual SIM - Black',
#   'Black',
#   13676,
#   18000,
#   '24%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S8  5.8" 64gb 4gb Single Sim',
#   'n/a',
#   170000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel 3310 Feature - Torch Light - 1000mAh - Black',
#   'Black',
#   10500,
#   11000,
#   '5%',
#   '3.9 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 12 Pro - 6.1" 128GB ROM, 6GB ROM 5G - Blue',
#   'Blue',
#   760000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel It 5606 Wireless FM - City Blue',
#   'City Blue',
#   18672,
#   30000,
#   '38%',
#   '4.2 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['itel 20000mAh Fast Charging,Bright Torch STAR200 MOBILE PowerBank',
#   'n/a',
#   15510,
#   25900,
#   '40%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 20000mAh Fast Charging Bright Torch STAR 200 Fast Power Bank',
#   'n/a',
#   15440,
#   20000,
#   '23%',
#   '4.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Atouch X19 Life- 10.1", 512GB ROM, 8GB RAM, 5G, Dual SIM',
#   '10.1", 512GB ROM, 8GB RAM, 5G, Dual SIM',
#   115000,
#   'N/A',
#   'N/A',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Samsung Galaxy Note 9 Single Sim 128gb/6gb 6.4'' Black",
#   'Black',
#   260500,
#   330000,
#   '21%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Genuine Comes With Both Type C And IPhone Plug&Play K8 Wireless Lavalier Microphone For IPhone, IPad, Type C Lapel Clip-on Mini Wireless Mic For TikTok Vlog YouTube, Facebook Live Stream, Auto-syncs Microphone (NO APP Or Bluetooth)',
#   'syncs Microphone (NO APP Or Bluetooth)',
#   9999,
#   'N/A',
#   'N/A',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 3310 Classic Mobile Phone Dual SIM Long  Of Grey',
#   'Grey',
#   31040,
#   32000,
#   '3%',
#   '3.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI 13C (4GB RAM + 128GB ROM) 5000MAH- Black',
#   'Black',
#   129500,
#   185000,
#   '30%',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Smart 8 6.6" 4GB RAM/128GB ROM Android T Go - Black',
#   'Black',
#   120000,
#   300000,
#   '60%',
#   'N/A',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 11 Pro Max (4GBRAM, 256GB ROM) 4G Midnight Green',
#   'n/a',
#   765000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI 13C 8GB RAM- 256GB ROM- 5000MAH- BLUE',
#   'BLUE',
#   165000,
#   190000,
#   '13%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Samsung Galaxy S9 Single Sim 64gb/4gb 5.8''",
#   'n/a',
#   175000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 6310 Classic Design, Wireless FM Feature Phone - Green',
#   'Green',
#   31040,
#   35000,
#   '11%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Samsung Galaxy S9+ ( S9 Plus ) Duel Sim 6.2'' Inch QHD 6GB+64GB 12MP+8MP 4G Smartphone - Midnight Black",
#   'Midnight Black',
#   270000,
#   290000,
#   '7%',
#   '1 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY AO5S 4GB/128GB DUAL SIM - 5000mAh BLACK',
#   '5000mAh BLACK',
#   186000,
#   400000,
#   '54%',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Smart 7 (X6516) 6.6" HD 2GB RAM/64GB ROM Android 12 - Black',
#   'Black',
#   108000,
#   120000,
#   '10%',
#   '4.2 out of 5',
#   'Official Store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 5310 XpressMusic Wireless FM Loudspeaker Dual SIM',
#   'n/a',
#   31040,
#   32000,
#   '3%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel Big Screen Dual Sim Bright Torch Phone- Explorer 500',
#   'Explorer 500',
#   17266,
#   21000,
#   '18%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel 2160 Wireless FM, Bright Torchlight, Call Recorder, Dual SIM Mobile - Black',
#   'Black',
#   14210,
#   15000,
#   '5%',
#   '4.2 out of 5',
#   'Official Store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S10 6.4" Single Sim 128gb/8gb',
#   'n/a',
#   270000,
#   'N/A',
#   'N/A',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oppo 99.9%NEW Refurbished A83 3180mAh 64GB Dual Card 5.7" Face',
#   'n/a',
#   72000,
#   120000,
#   '40%',
#   '4.5 out of 5',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 11 6.1-Inch Liquid Retina (4GB RAM, 128GB ROM) Purple',
#   'Inch Liquid Retina (4GB RAM, 128GB ROM) Purple',
#   755000,
#   'N/A',
#   'N/A',
#   '4.7 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI 13C 8GB RAM+ 256GB ROM 5000MAH - Midnight Black',
#   'Midnight Black',
#   165000,
#   180000,
#   '8%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S21 5G 8+128GB G991U - Purple',
#   'Purple',
#   380000,
#   480000,
#   '21%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
# ...
#   'thin Detachable Hard Cover Protective Back Case(Silver)',
#   2299,
#   3499,
#   '34%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Shipped from abroad'],
#  ['XIAOMI Redmi Note 12  8GB RAM 128GB ROM - Onyx Gray',
#   'Onyx Gray',
#   255000,
#   280000,
#   '9%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel A70 6.6” HD +screen,128 GB ROM +3RAM,5000mah',
#   'n/a',
#   103000,
#   105000,
#   '2%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel TV Touch- 3.5 Inch Touch Screen TV Phone - Black',
#   'Black',
#   32000,
#   40000,
#   '20%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Vivo Y17s 6.56" 6GB RAM 128GB ROM 4G LTE  Fingerprint - 5000mAh',
#   '5000mAh',
#   225000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi Note 13 Pro+ 5G-6.67",8/256GB,200/16MP-Moonlight White',
#   'Moonlight White',
#   593500,
#   600000,
#   '1%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno POP 8 (BG6) 6.6" HD+, 64GB ROM/3GB RAM 5000mAh - White',
#   'White',
#   124000,
#   140000,
#   '11%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Oneplus Nord N20 SE 6.56'' 4GB 128GB ROM Android 12 -Celestial Black",
#   'Celestial Black',
#   190000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia G10, 6.5" (4GB/64GB) Android 11, 4G, 5050mAh - Dark Blue',
#   'Dark Blue',
#   159999,
#   250000,
#   '36%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 110 Africa Edition Dual SIM Wireless FM, Torch Phone - 5 Pcs',
#   '5 Pcs',
#   74950,
#   80000,
#   '6%',
#   '3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy Z Fold 5 - 7.6" (12GB RAM, 512GB ROM) Android 13 (50/12/10)MP + 10MP Selfie - Snapdragon 5G - 4400mAh - Dual Sim - Cream',
#   'Cream',
#   4500000,
#   5000000,
#   '10%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 11 - 6.1" 128GB ROM, 4GB RAM, 3110mAh - Black',
#   'Black',
#   760000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno T301, Dual Sim, & Torch Light, 1150mAH, FM Radio, - Blue',
#   'Blue',
#   17500,
#   28000,
#   '38%',
#   '4.3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Samsung Galaxy S9  5.8'' 64gb/4gb Single Sim",
#   'n/a',
#   175000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["Samsung Galaxy S23 FE 5G 6.4'' 8GB RAM 256GB ROM Android 13 - Mint",
#   'Mint',
#   770000,
#   900000,
#   '14%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 2660 Flip - 2.8" - 4G LTE - Dual Sim - Black',
#   'Black',
#   135000,
#   150000,
#   '10%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 12 Pro Max - 128GB, 6GB RAM, 6.7-Inch,(12MP+12MP+12MP)-5G, Graphite',
#   '5G, Graphite',
#   822000,
#   'N/A',
#   'N/A',
#   '4.7 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['New Age 22500 Power Bank With Type-C Port Input & Output',
#   'C Port Input & Output',
#   19500,
#   25000,
#   '22%',
#   '3.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Siccoo Magic Voice Changer Function Four Sim P 14proGOLD',
#   'n/a',
#   30000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI Redmi Note 13 Pro - 8GB/256GB DUAL SIM- 5000mAh - Black',
#   'Black',
#   388000,
#   630000,
#   '38%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno POVA 6 Neo - 6.78" (256GB/8GB) 4G Dual SIM, 7000mAh - Black',
#   'Black',
#   339999,
#   450000,
#   '24%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Note 30 Pro - 6.67" (16GB RAM/256GB ROM) Android 13 - Gold',
#   'Gold',
#   429999,
#   550000,
#   '22%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel 3720 1.77 Inch Color Display, Flip Phone Black',
#   'Black',
#   23000,
#   'N/A',
#   'N/A',
#   '3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 6310 - 2.8-inch (8MB RAM, 16MB ROM) Dual Sim - Wireless FM',
#   'Wireless FM',
#   95000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel Great One - Gold',
#   'Gold',
#   33000,
#   'N/A',
#   'N/A',
#   '4.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 15 Pro 256GB - 5G - Black Titanium',
#   'Black Titanium',
#   2299000,
#   3900000,
#   '41%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel P40 - 6.6" (64GB/4GB) 4G Dual SIM, 6000mAh - Blue',
#   'Blue',
#   129999,
#   250000,
#   '48%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['itel It5606 2500mAh Big Battery Wireless FM Dual SIM Phone -Black',
#   'Black',
#   18990,
#   30000,
#   '37%',
#   '4.2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Atouch 6gb RAM 128gb ROM Educational Andriod Kids Tablet',
#   'n/a',
#   62000,
#   69000,
#   '10%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 13 Pro Max - 6.7" 128GB ROM, 6GB ROM 5G - Graphite',
#   'Graphite',
#   1000000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Camon 20 Premier 5G (CK9n) 512GB + 8GB RAM, 5000mAh - Blue',
#   'Blue',
#   599990,
#   800000,
#   '25%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Smart 7HD 2+2GB RAM+64GB ROM 4G - 5000mAh - White',
#   'White',
#   118200,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Jbl Tune 125tws Wireless In-ear Headphones - Black',
#   'Black',
#   78700,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['New Age 22500 Power Bank With Type-C Port  White',
#   'C Port  White',
#   18599,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno POVA 6 Neo - 6.78" (128GB/8GB) 4G Dual SIM, 7000mAh - Silver',
#   'Silver',
#   279999,
#   350000,
#   '20%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 5710 Xpress Audio - 2.4" 1450mAh Black',
#   '2.4" 1450mAh Black',
#   55000,
#   70000,
#   '21%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Super Fast 45W For S22/S22 Ultra/S22+/S21/S21 Ultra/S21+/S20/S20 Ultra/Note 10 Plus/Note 20 Ultra/Z Fold 4/Fold 3/Z Flip 4/Flip 3 5G, A53 USB C Charger WHITE',
#   'n/a',
#   14000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A71 5G Phone 6+128GB Android 13  48MP',
#   'n/a',
#   300000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Shipped from abroad'],
#  ['Nokia G21, 6.5", 4/64GB, 50/8/2/2MP Camera With AI Imaging - Blue',
#   'Blue',
#   159999,
#   250000,
#   '36%',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY A23-6.6"-64GB/4GB MEMORY -50MP/8MP CAMERA - 4G LTE',
#   '4G LTE',
#   229999,
#   300000,
#   '23%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI NOTE 13 PRO+ 8GB /256GB -DUAL SIM -5000mAh -WHITE',
#   'WHITE',
#   585000,
#   850000,
#   '31%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A54 Dual Sim - 8GB RAM - 256GB - 5G -Awesome White',
#   'Awesome White',
#   540000,
#   699000,
#   '23%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy S21 Ultra 5G 12+256GB G9980 Single Sim-White',
#   'White',
#   639999,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Shipped from abroad'],
#  ['Atouch Kids Educational Tab 128GB ROM 6GB RAM  Pre-installed Apps',
#   'installed Apps',
#   65000,
#   70000,
#   '7%',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung GALAXY AO5S 4GB/128GB DUAL SIM - 5000mAh BLACK',
#   '5000mAh BLACK',
#   238500,
#   400000,
#   '40%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A14 5G 64GB HDD - 4GB RAM - Black',
#   'Black',
#   304400,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 5310 16MB & 8MB RAM 1200mAh Battery',
#   'n/a',
#   32000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone12 Pro Max - 6.7" 128GB ROM, 6GB ROM 5G - Silver',
#   'Silver',
#   830000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Vivo Y27S 8GB/256GB DUAL SIM-5000MAH BLACK',
#   '5000MAH BLACK',
#   305280,
#   350000,
#   '13%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel Q8-3.5inch Screen, Spot Torch Light, Analog TV,TRIO SIM-GOLD',
#   'GOLD',
#   24000,
#   'N/A',
#   'N/A',
#   '3.8 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel 5310 Fast Charge, 1.77 Inch, Magic Voice, Black',
#   'Black',
#   12000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy Note 10 256gb 8gb Single Sim 6.3"',
#   'n/a',
#   320000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['XIAOMI REDMI 13C 4GB RAM- 128GB ROM- 5000MAH- GREEN',
#   'GREEN',
#   135000,
#   180000,
#   '25%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['I20 Ultra Max Smart Watch 2.3+ 7 Straps + Earbuds +Case',
#   'n/a',
#   29500,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel L600 - 1.77 Inch, Big Speaker, Dual SIM, 1000Mah Battery - Black',
#   'Black',
#   13500,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel 3720 1.77 Inch Color Display, Flip Phone RED',
#   'n/a',
#   22000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 110 Africa Edition Wireless FM,',
#   'n/a',
#   19999,
#   28000,
#   '29%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel 3310 Feature - Torch Light - 1000mAh - Grey',
#   'Grey',
#   12998,
#   20000,
#   '35%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Atouch Educational Tablet For Kids (2-10yrs)128GB Rom 6GB Ram+Pouch',
#   '10yrs)128GB Rom 6GB Ram+Pouch',
#   62000,
#   65000,
#   '5%',
#   '3.9 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 210 Dual SIM, Opera Mini, Camera, Torch, FM  - Grey',
#   'Grey',
#   63500,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Spark 10 pro 6.7inch martphone 4GB RAM 256GB ROM 10Core Android12.0 -Black',
#   'Black',
#   97200,
#   144000,
#   '33%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Shipped from abroad'],
#  ['Nokia 5310 XpressMusic, Bluetooth, MP3, FM, Dual SIM',
#   'n/a',
#   30500,
#   40000,
#   '24%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Ultra I20 Ultra Max Suit 2.3 10 In 1 Set',
#   'n/a',
#   35000,
#   38500,
#   '9%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Note 12 - 6.7" (128GB/4+3GB) 4G Dual SIM, 5000mAh - Black',
#   'Black',
#   179999,
#   250000,
#   '28%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Atouch 32GB Storage 3GB RAM Pre-installed Apps  Wi-fi Kids Tablet',
#   'fi Kids Tablet',
#   70000,
#   85000,
#   '18%',
#   '2 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 5310 XpressMusic Wireless FM Loudspeaker Dual SIM -White',
#   'White',
#   32000,
#   'N/A',
#   'N/A',
#   '4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPHONE 12 PRO MAX  6.7" (12PM+12PM+12PM) 256+6GB RAM 3687mAh',
#   'n/a',
#   950000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno Spark 10 6.6" 8GB RAM/128GB ROM Android 12 - Black',
#   'Black',
#   169990,
#   490000,
#   '65%',
#   '2.5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Infinix Smart 8-X6525 Android Mobile Phone With 64GB + 3GB + FREE UMBRELLA',
#   'X6525 Android Mobile Phone With 64GB + 3GB + FREE UMBRELLA',
#   109000,
#   150000,
#   '27%',
#   'N/A',
#   'Not from official store',
#   'Express Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 12 6.1 Inches 5G , 64GB ROM, - Black',
#   'Black',
#   570000,
#   'N/A',
#   'N/A',
#   '3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Oppo RENO 11 5G 12GB RAM 256GB ROM 4800mAh GREEN',
#   'n/a',
#   573500,
#   800000,
#   '28%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ["XIAOMI Redmi 9c - 6.53'' (128GB/4GB) 4G Dual SIM, 5000mAh",
#   "6.53'' (128GB/4GB) 4G Dual SIM, 5000mAh",
#   120000,
#   165000,
#   '27%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Ellington 6 Way Surge-Protector  Extension Socket',
#   'Protector  Extension Socket',
#   24500,
#   30000,
#   '18%',
#   '4.4 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Motorola Moto G54 6.5" 8GB RAM, 256GB ROM Android 13 - Blue',
#   'Blue',
#   300000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['SMALL 2160Wireless Fm, Torchlight Phones , Dual SIM - Dark Blue Small Cheapest Button Phone For Cheap Price',
#   'Dark Blue Small Cheapest Button Phone For Cheap Price',
#   23000,
#   'N/A',
#   'N/A',
#   '4.7 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Apple IPhone 11 Pro Max - 6.5" - 4GB RAM, 64GB ROM - Gold',
#   'Gold',
#   620000,
#   'N/A',
#   'N/A',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Nokia 150 - Dual Sim -2.4" -Camera - Torch-1020mAh-Black',
#   'Black',
#   27000,
#   'N/A',
#   'N/A',
#   '5 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Samsung Galaxy A15 6.5" 4GB RAM/128GB ROM Android 14 - Light /Blue',
#   'Light /Blue',
#   223900,
#   6000000,
#   '96%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Tecno T301 Dual Sim With Camera & TorchLight Fm Loud Speaker',
#   'n/a',
#   17600,
#   29000,
#   '39%',
#   'N/A',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ['Bontel L800 Feature Phone With Big Torch Light,1,000 MAh',
#   'n/a',
#   12990,
#   19000,
#   '32%',
#   '3 out of 5',
#   'Not from official store',
#   'Normal Shipping',
#   'Not shipped from abroad'],
#  ...]

# %%
products_df = pd.DataFrame(products, columns = ['Name', 'Color', 'New_Price', 'Old_Price', 'Discount', 'Rating', 'Store_Name', 'Shipping_Type', 'Shipped_From'])
products_df
# Out:
#                                                    Name      Color  New_Price  \
# 0     itel 20000mAh Fast Charging, Bright Torch STAR...        n/a      15990
# 1     Nokia 110 Africa Edition Dual SIM Wireless FM,...        n/a      13871
# 2     itel 2163 Wireless FM Torchlight Dual SIM - Black      Black      11500
# 3     itel 2163 Wireless FM Torchlight Dual SIM - Black      Black      11494
# 4     FreeYond M5,4GB+128GB,4G 6.52" Smartphone 5000...       Grey      97000
# ...                                                 ...        ...        ...
# 1995  Reno 8 Pro 6.8inch Smartphone    6gb  RaM 128G...        n/a     114000
# 1996                     Nokia 3310 Classic Mobile Grey       Grey      32000
# 1997  Samsung GALAXY A35 5G 8/256GB DUAL SIM- AWESOM...    5000MAH     541000
# 1998  Nokia 3310 Classic Mobile Phone Dual SIM Long ...  Dark Blue      32000
# 1999  Samsung Galaxy S23 Ultra S918U Single Sim 5G 8...        n/a     900000
#
#      Old_Price Discount        Rating               Store_Name  \
# 0        19790      19%    4 out of 5  Not from official store
# 1        18000      23%  4.1 out of 5  Not from official store
# 2        15500      26%    4 out of 5           Official Store
# 3        15000      23%  4.2 out of 5           Official Store
# 4       142498      32%  3.7 out of 5  Not from official store
# ...        ...      ...           ...                      ...
# 1995    163200      30%           N/A  Not from official store
# 1996     35000       9%           N/A  Not from official store
# 1997    620000      13%           N/A  Not from official store
# 1998     35000       9%           N/A  Not from official store
# 1999   2302600      61%           N/A  Not from official store
#
#          Shipping_Type             Shipped_From
# 0      Normal Shipping  Not shipped from abroad
# 1     Express Shipping  Not shipped from abroad
# 2     Express Shipping  Not shipped from abroad
# 3      Normal Shipping  Not shipped from abroad
# 4     Express Shipping  Not shipped from abroad
# ...                ...                      ...
# 1995   Normal Shipping      Shipped from abroad
# 1996   Normal Shipping  Not shipped from abroad
# 1997   Normal Shipping  Not shipped from abroad
# 1998   Normal Shipping  Not shipped from abroad
# 1999   Normal Shipping      Shipped from abroad
#
# [2000 rows x 9 columns]

# %%
products_df.describe()
# Out:
#           New_Price
# count  2.000000e+03
# mean   3.296050e+05
# std    4.755620e+05
# min    3.500000e+02
# 25%    4.060000e+04
# 50%    1.650000e+05
# 75%    4.034998e+05
# max    4.900000e+06

# %%
products_df.to_csv(r'Mobile_Phones.csv', index = False)
